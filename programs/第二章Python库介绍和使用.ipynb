# %% [markdown]
# ## 2.2.1Numpy库的介绍和使用

# %%
# %matplotlib inline
## 显示的图片格式（mac中的高清格式），还可以设置为"bmp"等格式
# %config InlineBackend.figure_format = "retina"

# %%
## 库的导入
import numpy as np

# %%
## 生成一个数组
A = np.array([[1,2,3,4],[5,6,7,8]])
A
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
## 改变数组的维度,默认是按照行优先改变数据维度
A.reshape((4,-1))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
## order="F",指按照列优先改变数据维度
A.reshape((4,2),order="F")
# Out:
# array([[1, 3],
#        [5, 7],
#        [2, 4],
#        [6, 8]])

# %%
## 提取数组中的元素(提取第一行)
A[1,:]
# Out:
# array([5, 6, 7, 8])

# %%
## 提取一列并修改值为1
A[:,2]=1
A
# Out:
# array([[1, 2, 1, 4],
#        [5, 6, 1, 8]])

# %%
## 提取指定的行和列(前两行的1，2列)
A[0:2,1:3]
# Out:
# array([[2, 1],
#        [6, 1]])

# %%
## 构建一个多维数组,数组包含两个矩阵，每个矩阵维2行4列
B = np.array([A,A*2])
B
# Out:
# array([[[ 1,  2,  1,  4],
#         [ 5,  6,  1,  8]],
#
#        [[ 2,  4,  2,  8],
#         [10, 12,  2, 16]]])

# %%
## 查看数组的维度
B.shape
# Out:
# (2, 2, 4)

# %%
## 在1～15之间生成等间距向量
np.linspace(start=1,stop=15,num=5)
# Out:
# array([  1. ,   4.5,   8. ,  11.5,  15. ])

# %%
## 以固定的长度生成向量
np.arange(1,15,5)
# Out:
# array([ 1,  6, 11])

# %%
## 生成全0数组
np.zeros((2,3))
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
## 生成全1数组
np.ones((2,3))
# Out:
# array([[ 1.,  1.,  1.],
#        [ 1.,  1.,  1.]])

# %%
## 生成单位数组
np.eye(3)
# Out:
# array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]])

# %%
## 生成对角数组
np.diag(np.arange(1,15,5))
# Out:
# array([[ 1,  0,  0],
#        [ 0,  6,  0],
#        [ 0,  0, 11]])

# %%
## 得到矩阵的对角元素
np.diag(np.arange(9).reshape((3,3)))
# Out:
# array([0, 4, 8])

# %%
## 指定随机数生成种子
np.random.seed(2)
## 生成随机数
np.random.randn(3,3)
# Out:
# array([[-0.41675785, -0.05626683, -2.1361961 ],
#        [ 1.64027081, -1.79343559, -0.84174737],
#        [ 0.50288142, -1.24528809, -1.05795222]])

# %%
## 计算数组的转置
np.random.seed(2)
C = np.random.randn(3,3).T
C
# Out:
# array([[-0.41675785,  1.64027081,  0.50288142],
#        [-0.05626683, -1.79343559, -1.24528809],
#        [-2.1361961 , -0.84174737, -1.05795222]])

# %%
## 将数组转化为矩阵并计算逆矩阵
D = np.mat(C).I
D
# Out:
# matrix([[ 0.42265324,  0.65304428, -0.5677797 ],
#         [ 1.29443848,  0.7541515 , -0.2724006 ],
#         [-1.88331793, -1.91864589,  0.41795959]])

# %%
## 检查相乘是否得到逆矩阵
np.mat(C)*D
# Out:
# matrix([[  1.00000000e+00,   8.43337040e-17,   4.42548666e-17],
#         [ -3.43586150e-16,   1.00000000e+00,  -2.49601463e-17],
#         [ -2.40764231e-17,   2.01146775e-16,   1.00000000e+00]])

# %%
## 计算矩阵的行列式
np.linalg.det(C)
# Out:
# 2.0090965940791263

# %%
## 矩阵的迹(矩阵对角线元素的和)
np.trace(C)
# Out:
# -3.2681456514626728

# %%
np.diag(C).sum()
# Out:
# -3.2681456514626728

# %% [markdown]
# ### numpy中的统计函数

# %%
## 计算均值
E = np.arange(10)
E.mean()
# Out:
# 4.5

# %%
## 计算标准差
E.std()
# Out:
# 2.8722813232690143

# %%
np.sqrt(((E-E.mean())**2).mean())
# Out:
# 2.8722813232690143

# %%
## 数据排序(二维数组则对每行排序)
np.sort([[2,5,3],[6,8,10]])
# Out:
# array([[ 2,  3,  5],
#        [ 6,  8, 10]])

# %%
## 数据排序(二维数组对每列排序)
np.sort([[2,5,3],[6,8,10]],axis=0)
# Out:
# array([[ 2,  5,  3],
#        [ 6,  8, 10]])

# %%
## 计算数组的百分位数
np.percentile(E,50)
# Out:
# 4.5

# %%
## 计算中位数(即百分之50分位数)
np.median(E)
# Out:
# 4.5

# %% [markdown]
# ## pandas库的简单介绍和使用

# %%
## 导入pandas库
import pandas as pd

# %%
## 读取数据集csv数据
Iris = pd.read_csv("/Users/daitu/慕课/Python机器学习与人工智能入门/data/Iris.csv")
## 查看数据的前几行
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## 查看数据的描述
Iris.describe()
## 分别是数据每个特征的个数、均值、标准差、四分位数
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
## 提取数据中的某列,并查看前6个数据
Iris["SepalLengthCm"].head(6)
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# Name: SepalLengthCm, dtype: float64

# %%
## 提取数据的第二列,并查看前6个数据
Iris.iloc[:,2].head(6)
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# 5    3.9
# Name: SepalWidthCm, dtype: float64

# %%
## 提取数据的第2，3行
Iris.iloc[2:4,:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
## 绘制散点图
## 提取数据的第2，3,5列数据
data = Iris.iloc[:,[2,3,5]]
data.head()
# Out:
#    SepalWidthCm  PetalLengthCm      Species
# 0           3.5            1.4  Iris-setosa
# 1           3.0            1.4  Iris-setosa
# 2           3.2            1.3  Iris-setosa
# 3           3.1            1.5  Iris-setosa
# 4           3.6            1.4  Iris-setosa

# %%
## 绘制散点图
import matplotlib.pyplot as plt       ## 引入matplotlib库

data.plot(x = "SepalWidthCm",y = "PetalLengthCm",## X轴数据，Y轴数据
         kind = "scatter",figsize = (8,6),       ## 图像类型、大小
         )
plt.show()

# %%
## 并行计算apply函数,按照列计算和
Iris.iloc[:,0:5].apply(func=np.sum,axis=0)
# Out:
# Id               11325.0
# SepalLengthCm      876.5
# SepalWidthCm       458.1
# PetalLengthCm      563.8
# PetalWidthCm       179.8
# dtype: float64

# %%
## 构造一个dataframe
## 函数中是一个字典，字典中分别是列名和相应的样例值
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar'],
              'B' : ['one', 'one', 'two', 'three', 'two', 'two',],
              'C' : np.random.randn(6),
              'D' : np.random.randn(6)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.909008 -0.596160
# 1  bar    one  0.551454 -0.019130
# 2  foo    two  2.292208  1.175001
# 3  bar  three  0.041539 -0.747871
# 4  foo    two -1.117925  0.009025
# 5  bar    two  0.539058 -0.878108

# %%
##查看变量中有几种值
df["A"].unique()
# Out:
# array(['foo', 'bar'], dtype=object)

# %% [markdown]
# ## matplotlib的简单介绍

# %%
## 导入库
import matplotlib.pyplot as plt
## 图像在jupyter notebook中显示
# %matplotlib inline
## 显示的图片格式（mac中的高清格式），还可以设置为"bmp"等格式
# %config InlineBackend.figure_format = "retina"
## 输出图显示中文
from matplotlib.font_manager import FontProperties
fonts = FontProperties(fname = "/Library/Fonts/华文细黑.ttf",size=14)
## 引入3D坐标系
from mpl_toolkits.mplot3d import Axes3D
## cm模块提供大量的colormap函数
from matplotlib import cm

# %%
## 绘制一条曲线
X = np.linspace(1,15)
Y = np.sin(X)
plt.figure(figsize=(6,4))     # 图像的大小(宽：6，高：4)
plt.plot(X,Y,"r-o")           # 绘制X，Y,红色、直线、圆圈
plt.xlabel("X")               # X坐标轴的label
plt.ylabel("Y")               # Y坐标轴的label
plt.title("y = sin(x)")       # 图像的名字title
plt.grid("on")                # 图像中添加网格
plt.show()                    #显示图像

# %%
## 绘制多个图像窗口
xtick = [0,5,10,15]
xticklabel = [str(x)+"在这" for x in xtick ]
plt.figure(figsize=(10,8))        # 图像的大小(宽：10，高：8)
plt.subplot(2,2,1)                # 4个子图中的第1个子图
plt.plot(X,Y,"b-.s")              # 绘制X，Y,蓝色、虚线、矩形点
plt.xlabel(r"$\alpha$")           # X坐标轴的label,使用latex公式
plt.ylabel(r"$\beta$")            # Y坐标轴的label,使用latex公式
plt.title("$y = \sum sin(x)$")    # 图像的名字title,使用latex公式
plt.subplot(2,2,2)                # 4个子图中的第2个子图
plt.hist(Y, 20)                   # 直方图
plt.text(0,7,"直方图",fontproperties = fonts)# 在（0，7）添加文字
plt.xlabel("频数",fontproperties = fonts)    # X坐标轴的label,使用中文
plt.ylabel("取值",fontproperties = fonts)    # Y坐标轴的label,使用使用中文
plt.title("直方图",fontproperties = fonts)   # 图像的名字title,使用使用中文
plt.subplot(2,1,2)                # 4个子图中的第3,4个子图合为一个图
plt.step(X,Y,c="R",label = "sin(x)",linewidth=3)  # 阶梯图，红色，线宽－3，添加标签
plt.xlabel("X",fontproperties = fonts)    # X坐标轴的label,使用中文
plt.ylabel("Y",fontproperties = fonts)    # Y坐标轴的label,使用使用中文
plt.title("Bar",fontproperties = fonts)   # 图像的名字title,使用使用中文
plt.legend(loc = "lower right",fontsize = 16)# 图例在右下角，字体大小为16
plt.xticks(xtick,xticklabel,rotation = 45,fontproperties = fonts)# x轴的坐标取值,倾斜45度
plt.subplots_adjust(hspace = 0.35)## 调整图像之间的水平空间距离
plt.show()

# %%
## 绘制3D图像
x = np.linspace(-4,4,num=50)
y = np.linspace(-4,4,num=50)
X,Y = np.meshgrid(x,y)
Z = np.sin(np.sqrt(X**2+Y**2))

# %%
fig = plt.figure(figsize=(12,5))
## 第一个子图的坐标系设置为3D
ax1 = fig.add_subplot(121, projection='3d')
## 绘制曲面图，rstride:行的跨度, cstride:列的跨度, cmap:颜色,alpha:透明度
ax1.plot_surface(X, Y, Z, rstride=1, cstride=1,alpha= 0.5 ,cmap=plt.cm.coolwarm)
## 绘制Z轴方向的等高线（投影）,位置在Z＝1的平面
cset = ax1.contour(X, Y, Z, zdir="z", offset = 1,cmap=cm.CMRmap)
ax1.set_xlabel("X") 
ax1.set_xlim(-4, 4)           ## 设置X轴的绘图范围
ax1.set_ylabel("Y") 
ax1.set_ylim(-4, 4)           ## 设置Y轴的绘图范围
ax1.set_zlabel("Z")
ax1.set_zlim(-1, 1)           ## 设置Z轴的绘图范围
ax1.set_title("surface and contour")
## 图二：绘制三维的曲线
## 准备数据
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100) # 角度
z = np.linspace(-2, 2, 100)                     # Z坐标
r = z**2 + 1                                    # 半径
x = r * np.sin(theta)                           # X坐标
y = r * np.cos(theta)                           # y坐标
ax2 = plt.subplot(122,projection = "3d")
ax2.plot(x, y, z)     #绘制曲线
ax2.scatter3D(x,y,z,c = "r")                    #绘制红色三维散点
ax2.view_init(elev=20,azim=25)   # 设置轴的方位角和高程
ax2.set_title("Curve and scatter")
plt.show()

# %%
## 显示照片
from skimage.io import imread  ## 从skimage库中引入读取图片的函数
from skimage.color import rgb2gray ## 从skimage库中引入将RGB图片转化为灰度图像的函数
im = imread("/Users/daitu/慕课/Python机器学习与人工智能入门/data/莱娜.tiff")
imgray = rgb2gray(im)
## 显示图片
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(im)
plt.axis("off")     ## 不显示坐标轴
plt.title("RGB Image")
plt.subplot(1,2,2)
plt.imshow(imgray,cmap = plt.cm.gray)
plt.axis("off")     ## 不显示坐标轴
plt.title("Gray Image")
plt.show()

# %% [markdown]
# ## stasmodels库的简单介绍和应用
# **一个线性回归的应用**

# %%
## 加载库
import numpy as np
## 加载statsmodels 的api
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
## 生成数据集
data = pd.DataFrame({"X":np.arange(10,20,0.25)})
data["Y"] = 2*data["X"]+1+np.random.randn(40)
data.head()
# Out:
#        X          Y
# 0  10.00  20.867671
# 1  10.25  21.460430
# 2  10.50  22.326003
# 3  10.75  20.459677
# 4  11.00  23.046256

# %%
# 拟合一个线性回归模型,y = a * x + b
mod = smf.ols("Y ~ X", data).fit()

# %%
## 查看模型输出的结果
print(mod.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     1188.
# Date:                Fri, 02 Feb 2018   Prob (F-statistic):           2.82e-30
# Time:                        12:42:04   Log-Likelihood:                -59.405
# No. Observations:                  40   AIC:                             122.8
# Df Residuals:                      38   BIC:                             126.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0910      0.910     -0.100      0.921      -1.933       1.751
# ...

# %%
## 查看截距和系数
mod.params
# Out:
# Intercept   -0.090995
# X            2.070120
# dtype: float64

# %%
"y = "+str(mod.params[1])+"*x"+str(mod.params[0])
# Out:
# 'y = 2.03711036459*x0.392236372979'

# %%
## 查看线性回归的散点图，
data.plot(x = "X",y = "Y",kind = "scatter",figsize=(8,5))
plt.plot(data["X"],mod.params[0]+mod.params[1]*data["X"],"r")
plt.text(10,38,"y = "+str(round(mod.params[1],4))+"*x"+str(round(mod.params[0],4)))
plt.title("simple linear regression")
plt.show()

# %% [markdown]
# ## scikit-learn库的简单介绍和使用
